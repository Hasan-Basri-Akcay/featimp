# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sklearn.datasets import load_diabetes
from sklearn.preprocessing import OrdinalEncoder

from featimp import (
    get_corr_importances,
    get_chi2_crosstab_importances,
    get_chi2_importances,
    get_anova_importances,
    get_mutual_info_importances,
    get_ml_importances,
    get_permutation_importances,
    get_feature_importances,
    )

sns.set()
warnings.simplefilter("ignore")
cm = sns.color_palette("coolwarm", as_cmap=True)

# %%
column_a = np.random.rand(1, 1000)
column_b = np.random.rand(1, 1000)
column_c = np.random.randint(2, size=1000)
column_d = np.random.randint(10, size=1000)
column_e = np.random.normal(0, 1, size=1000)
column_f = np.random.choice([True, False], 1000)
column_g = np.random.choice([1, 0], 1000)
test_df = pd.DataFrame()
test_df['a'] = column_a[0]
test_df['b'] = column_b[0]
test_df['c'] = column_c
test_df['d'] = column_d
test_df['e'] = column_e
test_df['f'] = column_f
test_df['g'] = column_g
test_df['target_reg'] = column_a[0]
test_df['target_clf_binary'] = column_c
test_df['target_clf_multi'] = column_d
display(test_df.head())
# Out:
#           a         b  c  d         e      f  g  target_reg  \
# 0  0.657793  0.376991  1  0  0.743753  False  1    0.657793
# 1  0.477385  0.646920  1  5 -1.181454   True  1    0.477385
# 2  0.060299  0.820574  1  1 -2.511020   True  0    0.060299
# 3  0.148096  0.822287  1  0 -0.683230   True  0    0.148096
# 4  0.089420  0.992849  1  1  0.227742   True  0    0.089420
#
#    target_clf_binary  target_clf_multi
# 0                  1                 0
# 1                  1                 5
# 2                  1                 1
# 3                  1                 0
# 4                  1                 1

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_reg', task='reg', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_e0462_row0_col0, #T_e0462_row0_col2, #T_e0462_row0_col4, #T_e0462_row0_col5, #T_e0462_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e0462_row0_col1, #T_e0462_row1_col1, #T_e0462_row1_col3, #T_e0462_row1_col4, #T_e0462_row2_col0, #T_e0462_row2_col1, #T_e0462_row2_col3, #T_e0462_row2_col4, #T_e0462_row2_col5, #T_e0462_row3_col0, #T_e0462_row3_col1, #T_e0462_row3_col2, #T_e0462_row3_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e0462_row0_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e0462_row1_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e0462_row1_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_e0462_row1_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e0462_row2_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_e0462_row3_col5 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# </style>
# <table id="T_e0462_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >ANOVA</th>
#       <th class="col_heading level0 col2" >LGBM Imp.</th>
#       <th class="col_heading level0 col3" >PI mean</th>
#       <th class="col_heading level0 col4" >PI std</th>
#       <th class="col_heading level0 col5" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0462_level0_row0" class="row_heading level0 row0" >a</th>
#       <td id="T_e0462_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e0462_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_e0462_row0_col2" class="data row0 col2" >1526.300000</td>
#       <td id="T_e0462_row0_col3" class="data row0 col3" >0.415271</td>
#       <td id="T_e0462_row0_col4" class="data row0 col4" >0.016984</td>
#       <td id="T_e0462_row0_col5" class="data row0 col5" >0.353452</td>
#     </tr>
#     <tr>
#       <th id="T_e0462_level0_row1" class="row_heading level0 row1" >b</th>
#       <td id="T_e0462_row1_col0" class="data row1 col0" >0.045699</td>
#       <td id="T_e0462_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_e0462_row1_col2" class="data row1 col2" >345.500000</td>
#       <td id="T_e0462_row1_col3" class="data row1 col3" >-0.000010</td>
#       <td id="T_e0462_row1_col4" class="data row1 col4" >0.000018</td>
#       <td id="T_e0462_row1_col5" class="data row1 col5" >-0.174553</td>
#     </tr>
#     <tr>
#       <th id="T_e0462_level0_row2" class="row_heading level0 row2" >e</th>
#       <td id="T_e0462_row2_col0" class="data row2 col0" >0.002807</td>
#       <td id="T_e0462_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_e0462_row2_col2" class="data row2 col2" >368.100000</td>
#       <td id="T_e0462_row2_col3" class="data row2 col3" >-0.000001</td>
#       <td id="T_e0462_row2_col4" class="data row2 col4" >0.000020</td>
#       <td id="T_e0462_row2_col5" class="data row2 col5" >-0.178899</td>
#     </tr>
#     <tr>
#       <th id="T_e0462_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_e0462_row3_col0" class="data row3 col0" >0.005998</td>
#       <td id="T_e0462_row3_col1" class="data row3 col1" >0.002000</td>
#       <td id="T_e0462_row3_col2" class="data row3 col2" >2.203786</td>
#       <td id="T_e0462_row3_col3" class="data row3 col3" >4.404720</td>
#       <td id="T_e0462_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_e0462_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_clf_binary', task='clf_binary', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_659f7_row0_col0, #T_659f7_row0_col3, #T_659f7_row0_col5, #T_659f7_row0_col8, #T_659f7_row1_col7, #T_659f7_row3_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_659f7_row0_col1, #T_659f7_row0_col2, #T_659f7_row0_col4, #T_659f7_row0_col6, #T_659f7_row1_col0, #T_659f7_row1_col1, #T_659f7_row1_col2, #T_659f7_row1_col3, #T_659f7_row1_col4, #T_659f7_row2_col1, #T_659f7_row2_col2, #T_659f7_row2_col4, #T_659f7_row2_col6, #T_659f7_row2_col8, #T_659f7_row3_col1, #T_659f7_row3_col2, #T_659f7_row3_col3, #T_659f7_row3_col4, #T_659f7_row3_col5, #T_659f7_row3_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_659f7_row0_col7 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_659f7_row1_col5 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_659f7_row1_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_659f7_row1_col8 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_659f7_row2_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_659f7_row2_col3 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_659f7_row2_col5 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_659f7_row2_col7 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_659f7_row3_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_659f7_row3_col8 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# </style>
# <table id="T_659f7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col2" >Chi_Square</th>
#       <th class="col_heading level0 col3" >ANOVA</th>
#       <th class="col_heading level0 col4" >MI Scores</th>
#       <th class="col_heading level0 col5" >LGBM Imp.</th>
#       <th class="col_heading level0 col6" >PI mean</th>
#       <th class="col_heading level0 col7" >PI std</th>
#       <th class="col_heading level0 col8" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_659f7_level0_row0" class="row_heading level0 row0" >b</th>
#       <td id="T_659f7_row0_col0" class="data row0 col0" >0.049603</td>
#       <td id="T_659f7_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_659f7_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_659f7_row0_col3" class="data row0 col3" >2.461587</td>
#       <td id="T_659f7_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_659f7_row0_col5" class="data row0 col5" >43.200000</td>
#       <td id="T_659f7_row0_col6" class="data row0 col6" >-0.000112</td>
#       <td id="T_659f7_row0_col7" class="data row0 col7" >0.039444</td>
#       <td id="T_659f7_row0_col8" class="data row0 col8" >0.150566</td>
#     </tr>
#     <tr>
#       <th id="T_659f7_level0_row1" class="row_heading level0 row1" >a</th>
#       <td id="T_659f7_row1_col0" class="data row1 col0" >0.002459</td>
#       <td id="T_659f7_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_659f7_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_659f7_row1_col3" class="data row1 col3" >0.006032</td>
#       <td id="T_659f7_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_659f7_row1_col5" class="data row1 col5" >38.000000</td>
#       <td id="T_659f7_row1_col6" class="data row1 col6" >0.003759</td>
#       <td id="T_659f7_row1_col7" class="data row1 col7" >0.043586</td>
#       <td id="T_659f7_row1_col8" class="data row1 col8" >-0.050499</td>
#     </tr>
#     <tr>
#       <th id="T_659f7_level0_row2" class="row_heading level0 row2" >e</th>
#       <td id="T_659f7_row2_col0" class="data row2 col0" >0.028557</td>
#       <td id="T_659f7_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_659f7_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_659f7_row2_col3" class="data row2 col3" >0.814530</td>
#       <td id="T_659f7_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_659f7_row2_col5" class="data row2 col5" >32.800000</td>
#       <td id="T_659f7_row2_col6" class="data row2 col6" >-0.016408</td>
#       <td id="T_659f7_row2_col7" class="data row2 col7" >0.028668</td>
#       <td id="T_659f7_row2_col8" class="data row2 col8" >-0.100067</td>
#     </tr>
#     <tr>
#       <th id="T_659f7_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_659f7_row3_col0" class="data row3 col0" >0.004001</td>
#       <td id="T_659f7_row3_col1" class="data row3 col1" >0.001000</td>
#       <td id="T_659f7_row3_col2" class="data row3 col2" >0.001000</td>
#       <td id="T_659f7_row3_col3" class="data row3 col3" >0.003998</td>
#       <td id="T_659f7_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_659f7_row3_col5" class="data row3 col5" >2.160858</td>
#       <td id="T_659f7_row3_col6" class="data row3 col6" >4.616494</td>
#       <td id="T_659f7_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_659f7_row3_col8" class="data row3 col8" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_clf_multi', task='clf_multiable', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_f6a2a_row0_col0, #T_f6a2a_row0_col1, #T_f6a2a_row0_col3, #T_f6a2a_row0_col5, #T_f6a2a_row1_col0, #T_f6a2a_row1_col1, #T_f6a2a_row1_col2, #T_f6a2a_row1_col3, #T_f6a2a_row1_col5, #T_f6a2a_row2_col0, #T_f6a2a_row2_col1, #T_f6a2a_row2_col3, #T_f6a2a_row2_col5, #T_f6a2a_row2_col7, #T_f6a2a_row3_col0, #T_f6a2a_row3_col1, #T_f6a2a_row3_col2, #T_f6a2a_row3_col3, #T_f6a2a_row3_col4, #T_f6a2a_row3_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f6a2a_row0_col2, #T_f6a2a_row0_col6, #T_f6a2a_row0_col7, #T_f6a2a_row1_col4, #T_f6a2a_row3_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f6a2a_row0_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_f6a2a_row1_col6 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_f6a2a_row1_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_f6a2a_row2_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_f6a2a_row2_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_f6a2a_row2_col6 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_f6a2a_row3_col7 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# </style>
# <table id="T_f6a2a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col1" >Chi_Square</th>
#       <th class="col_heading level0 col2" >ANOVA</th>
#       <th class="col_heading level0 col3" >MI Scores</th>
#       <th class="col_heading level0 col4" >LGBM Imp.</th>
#       <th class="col_heading level0 col5" >PI mean</th>
#       <th class="col_heading level0 col6" >PI std</th>
#       <th class="col_heading level0 col7" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6a2a_level0_row0" class="row_heading level0 row0" >e</th>
#       <td id="T_f6a2a_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_f6a2a_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_f6a2a_row0_col2" class="data row0 col2" >1.480224</td>
#       <td id="T_f6a2a_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_f6a2a_row0_col4" class="data row0 col4" >129.400000</td>
#       <td id="T_f6a2a_row0_col5" class="data row0 col5" >0.003256</td>
#       <td id="T_f6a2a_row0_col6" class="data row0 col6" >0.025672</td>
#       <td id="T_f6a2a_row0_col7" class="data row0 col7" >0.126924</td>
#     </tr>
#     <tr>
#       <th id="T_f6a2a_level0_row1" class="row_heading level0 row1" >a</th>
#       <td id="T_f6a2a_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_f6a2a_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_f6a2a_row1_col2" class="data row1 col2" >0.000205</td>
#       <td id="T_f6a2a_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_f6a2a_row1_col4" class="data row1 col4" >130.500000</td>
#       <td id="T_f6a2a_row1_col5" class="data row1 col5" >-0.000877</td>
#       <td id="T_f6a2a_row1_col6" class="data row1 col6" >0.024623</td>
#       <td id="T_f6a2a_row1_col7" class="data row1 col7" >-0.043695</td>
#     </tr>
#     <tr>
#       <th id="T_f6a2a_level0_row2" class="row_heading level0 row2" >b</th>
#       <td id="T_f6a2a_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_f6a2a_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_f6a2a_row2_col2" class="data row2 col2" >1.167788</td>
#       <td id="T_f6a2a_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_f6a2a_row2_col4" class="data row2 col4" >126.800000</td>
#       <td id="T_f6a2a_row2_col5" class="data row2 col5" >-0.001461</td>
#       <td id="T_f6a2a_row2_col6" class="data row2 col6" >0.018185</td>
#       <td id="T_f6a2a_row2_col7" class="data row2 col7" >-0.083229</td>
#     </tr>
#     <tr>
#       <th id="T_f6a2a_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_f6a2a_row3_col0" class="data row3 col0" >0.001001</td>
#       <td id="T_f6a2a_row3_col1" class="data row3 col1" >0.002000</td>
#       <td id="T_f6a2a_row3_col2" class="data row3 col2" >0.003001</td>
#       <td id="T_f6a2a_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_f6a2a_row3_col4" class="data row3 col4" >9.627041</td>
#       <td id="T_f6a2a_row3_col5" class="data row3 col5" >4.631765</td>
#       <td id="T_f6a2a_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_f6a2a_row3_col7" class="data row3 col7" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_reg', task='reg', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_fd423_row0_col0, #T_fd423_row0_col1, #T_fd423_row0_col3, #T_fd423_row1_col0, #T_fd423_row1_col3, #T_fd423_row1_col5, #T_fd423_row2_col0, #T_fd423_row2_col2, #T_fd423_row2_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fd423_row0_col2, #T_fd423_row0_col4, #T_fd423_row0_col5, #T_fd423_row1_col1, #T_fd423_row2_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fd423_row1_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_fd423_row1_col4 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_fd423_row2_col1 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_fd423_row2_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_fd423_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >ANOVA</th>
#       <th class="col_heading level0 col2" >LGBM Imp.</th>
#       <th class="col_heading level0 col3" >PI mean</th>
#       <th class="col_heading level0 col4" >PI std</th>
#       <th class="col_heading level0 col5" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd423_level0_row0" class="row_heading level0 row0" >d</th>
#       <td id="T_fd423_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_fd423_row0_col1" class="data row0 col1" >0.000205</td>
#       <td id="T_fd423_row0_col2" class="data row0 col2" >168.200000</td>
#       <td id="T_fd423_row0_col3" class="data row0 col3" >-0.000249</td>
#       <td id="T_fd423_row0_col4" class="data row0 col4" >0.002737</td>
#       <td id="T_fd423_row0_col5" class="data row0 col5" >0.083333</td>
#     </tr>
#     <tr>
#       <th id="T_fd423_level0_row1" class="row_heading level0 row1" >c</th>
#       <td id="T_fd423_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_fd423_row1_col1" class="data row1 col1" >0.006032</td>
#       <td id="T_fd423_row1_col2" class="data row1 col2" >101.600000</td>
#       <td id="T_fd423_row1_col3" class="data row1 col3" >-0.000508</td>
#       <td id="T_fd423_row1_col4" class="data row1 col4" >0.002223</td>
#       <td id="T_fd423_row1_col5" class="data row1 col5" >-0.083333</td>
#     </tr>
#     <tr>
#       <th id="T_fd423_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_fd423_row2_col0" class="data row2 col0" >0.002004</td>
#       <td id="T_fd423_row2_col1" class="data row2 col1" >0.002996</td>
#       <td id="T_fd423_row2_col2" class="data row2 col2" >1.842107</td>
#       <td id="T_fd423_row2_col3" class="data row2 col3" >2.612047</td>
#       <td id="T_fd423_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_fd423_row2_col5" class="data row2 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_clf_binary', task='clf_binary', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_3a9ee_row0_col0, #T_3a9ee_row0_col3, #T_3a9ee_row1_col0, #T_3a9ee_row1_col1, #T_3a9ee_row1_col2, #T_3a9ee_row1_col3, #T_3a9ee_row1_col4, #T_3a9ee_row1_col6, #T_3a9ee_row1_col7, #T_3a9ee_row1_col8, #T_3a9ee_row2_col0, #T_3a9ee_row2_col2, #T_3a9ee_row2_col3, #T_3a9ee_row2_col5, #T_3a9ee_row2_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3a9ee_row0_col1, #T_3a9ee_row0_col2, #T_3a9ee_row0_col4, #T_3a9ee_row0_col7, #T_3a9ee_row0_col8, #T_3a9ee_row1_col5, #T_3a9ee_row2_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3a9ee_row0_col5 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_3a9ee_row0_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_3a9ee_row2_col1, #T_3a9ee_row2_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_3a9ee_row2_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_3a9ee_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col2" >Chi_Square</th>
#       <th class="col_heading level0 col3" >ANOVA</th>
#       <th class="col_heading level0 col4" >MI Scores</th>
#       <th class="col_heading level0 col5" >LGBM Imp.</th>
#       <th class="col_heading level0 col6" >PI mean</th>
#       <th class="col_heading level0 col7" >PI std</th>
#       <th class="col_heading level0 col8" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a9ee_level0_row0" class="row_heading level0 row0" >c</th>
#       <td id="T_3a9ee_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_3a9ee_row0_col1" class="data row0 col1" >0.997998</td>
#       <td id="T_3a9ee_row0_col2" class="data row0 col2" >493.000000</td>
#       <td id="T_3a9ee_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_3a9ee_row0_col4" class="data row0 col4" >0.693549</td>
#       <td id="T_3a9ee_row0_col5" class="data row0 col5" >100.000000</td>
#       <td id="T_3a9ee_row0_col6" class="data row0 col6" >0.509014</td>
#       <td id="T_3a9ee_row0_col7" class="data row0 col7" >0.046263</td>
#       <td id="T_3a9ee_row0_col8" class="data row0 col8" >0.085714</td>
#     </tr>
#     <tr>
#       <th id="T_3a9ee_level0_row1" class="row_heading level0 row1" >d</th>
#       <td id="T_3a9ee_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_3a9ee_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_3a9ee_row1_col2" class="data row1 col2" >0.000474</td>
#       <td id="T_3a9ee_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_3a9ee_row1_col4" class="data row1 col4" >0.007710</td>
#       <td id="T_3a9ee_row1_col5" class="data row1 col5" >129.800000</td>
#       <td id="T_3a9ee_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_3a9ee_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_3a9ee_row1_col8" class="data row1 col8" >-0.085714</td>
#     </tr>
#     <tr>
#       <th id="T_3a9ee_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_3a9ee_row2_col0" class="data row2 col0" >0.001044</td>
#       <td id="T_3a9ee_row2_col1" class="data row2 col1" >0.025990</td>
#       <td id="T_3a9ee_row2_col2" class="data row2 col2" >0.003000</td>
#       <td id="T_3a9ee_row2_col3" class="data row2 col3" >0.001001</td>
#       <td id="T_3a9ee_row2_col4" class="data row2 col4" >0.025998</td>
#       <td id="T_3a9ee_row2_col5" class="data row2 col5" >1.434914</td>
#       <td id="T_3a9ee_row2_col6" class="data row2 col6" >2.850217</td>
#       <td id="T_3a9ee_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_3a9ee_row2_col8" class="data row2 col8" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_clf_multi', task='clf_multiable', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_4539e_row0_col0, #T_4539e_row0_col1, #T_4539e_row0_col3, #T_4539e_row0_col4, #T_4539e_row0_col6, #T_4539e_row0_col7, #T_4539e_row2_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4539e_row0_col2, #T_4539e_row1_col0, #T_4539e_row1_col1, #T_4539e_row1_col2, #T_4539e_row1_col3, #T_4539e_row1_col5, #T_4539e_row1_col6, #T_4539e_row1_col7, #T_4539e_row2_col1, #T_4539e_row2_col2, #T_4539e_row2_col4, #T_4539e_row2_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4539e_row0_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_4539e_row1_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_4539e_row2_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_4539e_row2_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_4539e_row2_col7 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_4539e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col1" >Chi_Square</th>
#       <th class="col_heading level0 col2" >ANOVA</th>
#       <th class="col_heading level0 col3" >MI Scores</th>
#       <th class="col_heading level0 col4" >LGBM Imp.</th>
#       <th class="col_heading level0 col5" >PI mean</th>
#       <th class="col_heading level0 col6" >PI std</th>
#       <th class="col_heading level0 col7" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4539e_level0_row0" class="row_heading level0 row0" >d</th>
#       <td id="T_4539e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4539e_row0_col1" class="data row0 col1" >1849.020175</td>
#       <td id="T_4539e_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_4539e_row0_col3" class="data row0 col3" >2.300451</td>
#       <td id="T_4539e_row0_col4" class="data row0 col4" >4124.200000</td>
#       <td id="T_4539e_row0_col5" class="data row0 col5" >0.898634</td>
#       <td id="T_4539e_row0_col6" class="data row0 col6" >0.032561</td>
#       <td id="T_4539e_row0_col7" class="data row0 col7" >0.142857</td>
#     </tr>
#     <tr>
#       <th id="T_4539e_level0_row1" class="row_heading level0 row1" >c</th>
#       <td id="T_4539e_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_4539e_row1_col1" class="data row1 col1" >3.144871</td>
#       <td id="T_4539e_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_4539e_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_4539e_row1_col4" class="data row1 col4" >1541.600000</td>
#       <td id="T_4539e_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_4539e_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_4539e_row1_col7" class="data row1 col7" >-0.142857</td>
#     </tr>
#     <tr>
#       <th id="T_4539e_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_4539e_row2_col0" class="data row2 col0" >0.019792</td>
#       <td id="T_4539e_row2_col1" class="data row2 col1" >0.004000</td>
#       <td id="T_4539e_row2_col2" class="data row2 col2" >0.002003</td>
#       <td id="T_4539e_row2_col3" class="data row2 col3" >0.034829</td>
#       <td id="T_4539e_row2_col4" class="data row2 col4" >3.623749</td>
#       <td id="T_4539e_row2_col5" class="data row2 col5" >3.162700</td>
#       <td id="T_4539e_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_4539e_row2_col7" class="data row2 col7" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=[], bool_features=['f', 'g'], target='target_reg', task='reg', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_04bed_row0_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_04bed_row0_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_04bed_row0_col2, #T_04bed_row1_col0, #T_04bed_row1_col1, #T_04bed_row1_col4, #T_04bed_row2_col3, #T_04bed_row2_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_04bed_row0_col3, #T_04bed_row1_col3, #T_04bed_row1_col5, #T_04bed_row2_col0, #T_04bed_row2_col1, #T_04bed_row2_col2, #T_04bed_row2_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_04bed_row0_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_04bed_row0_col5 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_04bed_row1_col2 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# </style>
# <table id="T_04bed_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >ANOVA</th>
#       <th class="col_heading level0 col2" >LGBM Imp.</th>
#       <th class="col_heading level0 col3" >PI mean</th>
#       <th class="col_heading level0 col4" >PI std</th>
#       <th class="col_heading level0 col5" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04bed_level0_row0" class="row_heading level0 row0" >f</th>
#       <td id="T_04bed_row0_col0" class="data row0 col0" >0.012096</td>
#       <td id="T_04bed_row0_col1" class="data row0 col1" >0.146052</td>
#       <td id="T_04bed_row0_col2" class="data row0 col2" >71.100000</td>
#       <td id="T_04bed_row0_col3" class="data row0 col3" >-0.000484</td>
#       <td id="T_04bed_row0_col4" class="data row0 col4" >0.000695</td>
#       <td id="T_04bed_row0_col5" class="data row0 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_04bed_level0_row1" class="row_heading level0 row1" >g</th>
#       <td id="T_04bed_row1_col0" class="data row1 col0" >0.022627</td>
#       <td id="T_04bed_row1_col1" class="data row1 col1" >0.511223</td>
#       <td id="T_04bed_row1_col2" class="data row1 col2" >50.700000</td>
#       <td id="T_04bed_row1_col3" class="data row1 col3" >-0.000510</td>
#       <td id="T_04bed_row1_col4" class="data row1 col4" >0.001030</td>
#       <td id="T_04bed_row1_col5" class="data row1 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_04bed_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_04bed_row2_col0" class="data row2 col0" >0.004516</td>
#       <td id="T_04bed_row2_col1" class="data row2 col1" >0.003999</td>
#       <td id="T_04bed_row2_col2" class="data row2 col2" >1.322675</td>
#       <td id="T_04bed_row2_col3" class="data row2 col3" >2.490495</td>
#       <td id="T_04bed_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_04bed_row2_col5" class="data row2 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=[], bool_features=['f', 'g'], target='target_clf_binary', task='clf_binary', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_acac3_row0_col0, #T_acac3_row0_col1, #T_acac3_row0_col2, #T_acac3_row0_col3, #T_acac3_row0_col7, #T_acac3_row0_col8, #T_acac3_row1_col5, #T_acac3_row2_col4, #T_acac3_row2_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_acac3_row0_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_acac3_row0_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_acac3_row0_col6, #T_acac3_row1_col1, #T_acac3_row1_col4, #T_acac3_row1_col6, #T_acac3_row1_col8, #T_acac3_row2_col0, #T_acac3_row2_col2, #T_acac3_row2_col3, #T_acac3_row2_col5, #T_acac3_row2_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_acac3_row1_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_acac3_row1_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_acac3_row1_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_acac3_row1_col7 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_acac3_row2_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_acac3_row2_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_acac3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col2" >Chi_Square</th>
#       <th class="col_heading level0 col3" >ANOVA</th>
#       <th class="col_heading level0 col4" >MI Scores</th>
#       <th class="col_heading level0 col5" >LGBM Imp.</th>
#       <th class="col_heading level0 col6" >PI mean</th>
#       <th class="col_heading level0 col7" >PI std</th>
#       <th class="col_heading level0 col8" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acac3_level0_row0" class="row_heading level0 row0" >g</th>
#       <td id="T_acac3_row0_col0" class="data row0 col0" >0.044089</td>
#       <td id="T_acac3_row0_col1" class="data row0 col1" >0.027771</td>
#       <td id="T_acac3_row0_col2" class="data row0 col2" >0.977757</td>
#       <td id="T_acac3_row0_col3" class="data row0 col3" >1.943741</td>
#       <td id="T_acac3_row0_col4" class="data row0 col4" >0.023072</td>
#       <td id="T_acac3_row0_col5" class="data row0 col5" >61.700000</td>
#       <td id="T_acac3_row0_col6" class="data row0 col6" >0.027397</td>
#       <td id="T_acac3_row0_col7" class="data row0 col7" >0.050976</td>
#       <td id="T_acac3_row0_col8" class="data row0 col8" >0.102041</td>
#     </tr>
#     <tr>
#       <th id="T_acac3_level0_row1" class="row_heading level0 row1" >f</th>
#       <td id="T_acac3_row1_col0" class="data row1 col0" >0.015170</td>
#       <td id="T_acac3_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_acac3_row1_col2" class="data row1 col2" >0.105861</td>
#       <td id="T_acac3_row1_col3" class="data row1 col3" >0.229725</td>
#       <td id="T_acac3_row1_col4" class="data row1 col4" >0.019584</td>
#       <td id="T_acac3_row1_col5" class="data row1 col5" >123.400000</td>
#       <td id="T_acac3_row1_col6" class="data row1 col6" >0.023961</td>
#       <td id="T_acac3_row1_col7" class="data row1 col7" >0.030858</td>
#       <td id="T_acac3_row1_col8" class="data row1 col8" >-0.102041</td>
#     </tr>
#     <tr>
#       <th id="T_acac3_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_acac3_row2_col0" class="data row2 col0" >0.001999</td>
#       <td id="T_acac3_row2_col1" class="data row2 col1" >0.017000</td>
#       <td id="T_acac3_row2_col2" class="data row2 col2" >0.002000</td>
#       <td id="T_acac3_row2_col3" class="data row2 col3" >0.005004</td>
#       <td id="T_acac3_row2_col4" class="data row2 col4" >0.024022</td>
#       <td id="T_acac3_row2_col5" class="data row2 col5" >1.442639</td>
#       <td id="T_acac3_row2_col6" class="data row2 col6" >2.820678</td>
#       <td id="T_acac3_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_acac3_row2_col8" class="data row2 col8" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=[], bool_features=['f', 'g'], target='target_clf_multi', task='clf_multiable', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_4c37b_row0_col0, #T_4c37b_row0_col1, #T_4c37b_row0_col2, #T_4c37b_row0_col7, #T_4c37b_row1_col4, #T_4c37b_row1_col6, #T_4c37b_row2_col3, #T_4c37b_row2_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4c37b_row0_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_4c37b_row0_col4 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_4c37b_row0_col5, #T_4c37b_row1_col0, #T_4c37b_row1_col3, #T_4c37b_row1_col5, #T_4c37b_row1_col7, #T_4c37b_row2_col1, #T_4c37b_row2_col2, #T_4c37b_row2_col4, #T_4c37b_row2_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4c37b_row0_col6 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_4c37b_row1_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_4c37b_row1_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_4c37b_row2_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_4c37b_row2_col7 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# </style>
# <table id="T_4c37b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col1" >Chi_Square</th>
#       <th class="col_heading level0 col2" >ANOVA</th>
#       <th class="col_heading level0 col3" >MI Scores</th>
#       <th class="col_heading level0 col4" >LGBM Imp.</th>
#       <th class="col_heading level0 col5" >PI mean</th>
#       <th class="col_heading level0 col6" >PI std</th>
#       <th class="col_heading level0 col7" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c37b_level0_row0" class="row_heading level0 row0" >g</th>
#       <td id="T_4c37b_row0_col0" class="data row0 col0" >0.042983</td>
#       <td id="T_4c37b_row0_col1" class="data row0 col1" >5.459924</td>
#       <td id="T_4c37b_row0_col2" class="data row0 col2" >1.797239</td>
#       <td id="T_4c37b_row0_col3" class="data row0 col3" >0.013884</td>
#       <td id="T_4c37b_row0_col4" class="data row0 col4" >34.200000</td>
#       <td id="T_4c37b_row0_col5" class="data row0 col5" >-0.003666</td>
#       <td id="T_4c37b_row0_col6" class="data row0 col6" >0.008516</td>
#       <td id="T_4c37b_row0_col7" class="data row0 col7" >0.047619</td>
#     </tr>
#     <tr>
#       <th id="T_4c37b_level0_row1" class="row_heading level0 row1" >f</th>
#       <td id="T_4c37b_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_4c37b_row1_col1" class="data row1 col1" >2.761712</td>
#       <td id="T_4c37b_row1_col2" class="data row1 col2" >0.903954</td>
#       <td id="T_4c37b_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_4c37b_row1_col4" class="data row1 col4" >40.800000</td>
#       <td id="T_4c37b_row1_col5" class="data row1 col5" >-0.002057</td>
#       <td id="T_4c37b_row1_col6" class="data row1 col6" >0.009113</td>
#       <td id="T_4c37b_row1_col7" class="data row1 col7" >-0.047619</td>
#     </tr>
#     <tr>
#       <th id="T_4c37b_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_4c37b_row2_col0" class="data row2 col0" >0.015634</td>
#       <td id="T_4c37b_row2_col1" class="data row2 col1" >0.004000</td>
#       <td id="T_4c37b_row2_col2" class="data row2 col2" >0.002000</td>
#       <td id="T_4c37b_row2_col3" class="data row2 col3" >0.041092</td>
#       <td id="T_4c37b_row2_col4" class="data row2 col4" >2.683158</td>
#       <td id="T_4c37b_row2_col5" class="data row2 col5" >2.963346</td>
#       <td id="T_4c37b_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_4c37b_row2_col7" class="data row2 col7" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
