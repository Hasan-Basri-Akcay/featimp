# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sklearn.datasets import load_diabetes
from sklearn.preprocessing import OrdinalEncoder

from featimp import (
    get_corr_importances,
    get_chi2_crosstab_importances,
    get_chi2_importances,
    get_anova_importances,
    get_mutual_info_importances,
    get_ml_importances,
    get_permutation_importances,
    get_feature_importances,
    )

sns.set()
warnings.simplefilter("ignore")
cm = sns.light_palette("green", as_cmap=True)

# %%
column_a = np.random.rand(1, 1000)
column_b = np.random.rand(1, 1000)
column_c = np.random.randint(2, size=1000)
column_d = np.random.randint(10, size=1000)
column_e = np.random.normal(0, 1, size=1000)
test_df = pd.DataFrame()
test_df['a'] = column_a[0]
test_df['b'] = column_b[0]
test_df['c'] = column_c
test_df['d'] = column_d
test_df['e'] = column_e
test_df['target_reg'] = column_a[0]
test_df['target_clf_binary'] = column_c
test_df['target_clf_multi'] = column_d
display(test_df.head())
# Out:
#           a         b  c  d         e  target_reg  target_clf_binary  \
# 0  0.728332  0.501019  1  1  0.246834    0.728332                  1
# 1  0.326255  0.736472  0  8 -0.587401    0.326255                  0
# 2  0.421116  0.804867  1  5 -0.188332    0.421116                  1
# 3  0.524131  0.935239  0  8 -1.186317    0.524131                  0
# 4  0.204897  0.932672  0  9 -1.921467    0.204897                  0
#
#    target_clf_multi
# 0                 1
# 1                 8
# 2                 5
# 3                 8
# 4                 9

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_reg', task='reg', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_5600f_row0_col0, #T_5600f_row0_col2, #T_5600f_row0_col4, #T_5600f_row0_col5, #T_5600f_row3_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_5600f_row0_col1, #T_5600f_row1_col1, #T_5600f_row1_col3, #T_5600f_row1_col4, #T_5600f_row2_col1, #T_5600f_row2_col3, #T_5600f_row2_col4, #T_5600f_row2_col5, #T_5600f_row3_col0, #T_5600f_row3_col1, #T_5600f_row3_col2, #T_5600f_row3_col4, #T_5600f_row3_col5 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_5600f_row0_col3 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_5600f_row1_col0 {
#   background-color: #d3e7d3;
#   color: #000000;
# }
# #T_5600f_row1_col2, #T_5600f_row2_col2 {
#   background-color: #bcdcbc;
#   color: #000000;
# }
# #T_5600f_row1_col5 {
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_5600f_row2_col0 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# </style>
# <table id="T_5600f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >ANOVA</th>
#       <th class="col_heading level0 col2" >LGBM Imp.</th>
#       <th class="col_heading level0 col3" >PI mean</th>
#       <th class="col_heading level0 col4" >PI std</th>
#       <th class="col_heading level0 col5" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5600f_level0_row0" class="row_heading level0 row0" >a</th>
#       <td id="T_5600f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5600f_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_5600f_row0_col2" class="data row0 col2" >1498.900000</td>
#       <td id="T_5600f_row0_col3" class="data row0 col3" >0.395496</td>
#       <td id="T_5600f_row0_col4" class="data row0 col4" >0.016372</td>
#       <td id="T_5600f_row0_col5" class="data row0 col5" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_5600f_level0_row1" class="row_heading level0 row1" >b</th>
#       <td id="T_5600f_row1_col0" class="data row1 col0" >0.108286</td>
#       <td id="T_5600f_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_5600f_row1_col2" class="data row1 col2" >300.900000</td>
#       <td id="T_5600f_row1_col3" class="data row1 col3" >0.000002</td>
#       <td id="T_5600f_row1_col4" class="data row1 col4" >0.000024</td>
#       <td id="T_5600f_row1_col5" class="data row1 col5" >0.022159</td>
#     </tr>
#     <tr>
#       <th id="T_5600f_level0_row2" class="row_heading level0 row2" >e</th>
#       <td id="T_5600f_row2_col0" class="data row2 col0" >0.021587</td>
#       <td id="T_5600f_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_5600f_row2_col2" class="data row2 col2" >304.700000</td>
#       <td id="T_5600f_row2_col3" class="data row2 col3" >-0.000007</td>
#       <td id="T_5600f_row2_col4" class="data row2 col4" >0.000018</td>
#       <td id="T_5600f_row2_col5" class="data row2 col5" >0.000793</td>
#     </tr>
#     <tr>
#       <th id="T_5600f_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_5600f_row3_col0" class="data row3 col0" >0.003313</td>
#       <td id="T_5600f_row3_col1" class="data row3 col1" >0.000676</td>
#       <td id="T_5600f_row3_col2" class="data row3 col2" >1.810108</td>
#       <td id="T_5600f_row3_col3" class="data row3 col3" >4.073546</td>
#       <td id="T_5600f_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_5600f_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_clf_binary', task='clf_binary', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_72cf0_row0_col0, #T_72cf0_row0_col1, #T_72cf0_row0_col3, #T_72cf0_row1_col0, #T_72cf0_row1_col1, #T_72cf0_row1_col3, #T_72cf0_row1_col5, #T_72cf0_row2_col0, #T_72cf0_row2_col1, #T_72cf0_row2_col3, #T_72cf0_row2_col5, #T_72cf0_row3_col0, #T_72cf0_row3_col1, #T_72cf0_row3_col2, #T_72cf0_row3_col3, #T_72cf0_row3_col4, #T_72cf0_row3_col6, #T_72cf0_row3_col7 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_72cf0_row0_col2 {
#   background-color: #6cb56c;
#   color: #f1f1f1;
# }
# #T_72cf0_row0_col4, #T_72cf0_row0_col7, #T_72cf0_row1_col2, #T_72cf0_row2_col6, #T_72cf0_row3_col5 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_72cf0_row0_col5 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_72cf0_row0_col6, #T_72cf0_row1_col6 {
#   background-color: #229122;
#   color: #f1f1f1;
# }
# #T_72cf0_row1_col4 {
#   background-color: #209020;
#   color: #f1f1f1;
# }
# #T_72cf0_row1_col7 {
#   background-color: #62b062;
#   color: #f1f1f1;
# }
# #T_72cf0_row2_col2 {
#   background-color: #aad3aa;
#   color: #000000;
# }
# #T_72cf0_row2_col4 {
#   background-color: #349a34;
#   color: #f1f1f1;
# }
# #T_72cf0_row2_col7 {
#   background-color: #ddecdd;
#   color: #000000;
# }
# </style>
# <table id="T_72cf0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col1" >Chi_Square</th>
#       <th class="col_heading level0 col2" >ANOVA</th>
#       <th class="col_heading level0 col3" >MI Scores</th>
#       <th class="col_heading level0 col4" >LGBM Imp.</th>
#       <th class="col_heading level0 col5" >PI mean</th>
#       <th class="col_heading level0 col6" >PI std</th>
#       <th class="col_heading level0 col7" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72cf0_level0_row0" class="row_heading level0 row0" >e</th>
#       <td id="T_72cf0_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_72cf0_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_72cf0_row0_col2" class="data row0 col2" >3.522763</td>
#       <td id="T_72cf0_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_72cf0_row0_col4" class="data row0 col4" >28.200000</td>
#       <td id="T_72cf0_row0_col5" class="data row0 col5" >0.024125</td>
#       <td id="T_72cf0_row0_col6" class="data row0 col6" >0.031961</td>
#       <td id="T_72cf0_row0_col7" class="data row0 col7" >0.394665</td>
#     </tr>
#     <tr>
#       <th id="T_72cf0_level0_row1" class="row_heading level0 row1" >b</th>
#       <td id="T_72cf0_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_72cf0_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_72cf0_row1_col2" class="data row1 col2" >6.504797</td>
#       <td id="T_72cf0_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_72cf0_row1_col4" class="data row1 col4" >24.500000</td>
#       <td id="T_72cf0_row1_col5" class="data row1 col5" >0.007966</td>
#       <td id="T_72cf0_row1_col6" class="data row1 col6" >0.032003</td>
#       <td id="T_72cf0_row1_col7" class="data row1 col7" >0.228814</td>
#     </tr>
#     <tr>
#       <th id="T_72cf0_level0_row2" class="row_heading level0 row2" >a</th>
#       <td id="T_72cf0_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_72cf0_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_72cf0_row2_col2" class="data row2 col2" >1.786485</td>
#       <td id="T_72cf0_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_72cf0_row2_col4" class="data row2 col4" >22.300000</td>
#       <td id="T_72cf0_row2_col5" class="data row2 col5" >0.010284</td>
#       <td id="T_72cf0_row2_col6" class="data row2 col6" >0.037499</td>
#       <td id="T_72cf0_row2_col7" class="data row2 col7" >0.023914</td>
#     </tr>
#     <tr>
#       <th id="T_72cf0_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_72cf0_row3_col0" class="data row3 col0" >0.000996</td>
#       <td id="T_72cf0_row3_col1" class="data row3 col1" >0.000997</td>
#       <td id="T_72cf0_row3_col2" class="data row3 col2" >0.001995</td>
#       <td id="T_72cf0_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_72cf0_row3_col4" class="data row3 col4" >1.799254</td>
#       <td id="T_72cf0_row3_col5" class="data row3 col5" >3.853306</td>
#       <td id="T_72cf0_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_72cf0_row3_col7" class="data row3 col7" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_clf_multi', task='clf_multiable', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_c26fd_row0_col0, #T_c26fd_row0_col1, #T_c26fd_row0_col3, #T_c26fd_row0_col5, #T_c26fd_row1_col0, #T_c26fd_row1_col1, #T_c26fd_row1_col3, #T_c26fd_row1_col5, #T_c26fd_row2_col0, #T_c26fd_row2_col1, #T_c26fd_row2_col3, #T_c26fd_row2_col5, #T_c26fd_row3_col0, #T_c26fd_row3_col1, #T_c26fd_row3_col2, #T_c26fd_row3_col3, #T_c26fd_row3_col4, #T_c26fd_row3_col6, #T_c26fd_row3_col7 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_c26fd_row0_col2 {
#   background-color: #aed5ae;
#   color: #000000;
# }
# #T_c26fd_row0_col4, #T_c26fd_row0_col7, #T_c26fd_row1_col2, #T_c26fd_row1_col6, #T_c26fd_row3_col5 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_c26fd_row0_col6 {
#   background-color: #239123;
#   color: #f1f1f1;
# }
# #T_c26fd_row1_col4 {
#   background-color: #048204;
#   color: #f1f1f1;
# }
# #T_c26fd_row1_col7 {
#   background-color: #76ba76;
#   color: #f1f1f1;
# }
# #T_c26fd_row2_col2 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_c26fd_row2_col4 {
#   background-color: #028102;
#   color: #f1f1f1;
# }
# #T_c26fd_row2_col6 {
#   background-color: #2b952b;
#   color: #f1f1f1;
# }
# #T_c26fd_row2_col7 {
#   background-color: #b6d9b6;
#   color: #000000;
# }
# </style>
# <table id="T_c26fd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col1" >Chi_Square</th>
#       <th class="col_heading level0 col2" >ANOVA</th>
#       <th class="col_heading level0 col3" >MI Scores</th>
#       <th class="col_heading level0 col4" >LGBM Imp.</th>
#       <th class="col_heading level0 col5" >PI mean</th>
#       <th class="col_heading level0 col6" >PI std</th>
#       <th class="col_heading level0 col7" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c26fd_level0_row0" class="row_heading level0 row0" >e</th>
#       <td id="T_c26fd_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_c26fd_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_c26fd_row0_col2" class="data row0 col2" >0.264313</td>
#       <td id="T_c26fd_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_c26fd_row0_col4" class="data row0 col4" >139.700000</td>
#       <td id="T_c26fd_row0_col5" class="data row0 col5" >0.030873</td>
#       <td id="T_c26fd_row0_col6" class="data row0 col6" >0.018181</td>
#       <td id="T_c26fd_row0_col7" class="data row0 col7" >0.371117</td>
#     </tr>
#     <tr>
#       <th id="T_c26fd_level0_row1" class="row_heading level0 row1" >b</th>
#       <td id="T_c26fd_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_c26fd_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_c26fd_row1_col2" class="data row1 col2" >1.015544</td>
#       <td id="T_c26fd_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_c26fd_row1_col4" class="data row1 col4" >137.300000</td>
#       <td id="T_c26fd_row1_col5" class="data row1 col5" >0.018449</td>
#       <td id="T_c26fd_row1_col6" class="data row1 col6" >0.021378</td>
#       <td id="T_c26fd_row1_col7" class="data row1 col7" >0.184562</td>
#     </tr>
#     <tr>
#       <th id="T_c26fd_level0_row2" class="row_heading level0 row2" >a</th>
#       <td id="T_c26fd_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_c26fd_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_c26fd_row2_col2" class="data row2 col2" >0.044079</td>
#       <td id="T_c26fd_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_c26fd_row2_col4" class="data row2 col4" >138.500000</td>
#       <td id="T_c26fd_row2_col5" class="data row2 col5" >0.016955</td>
#       <td id="T_c26fd_row2_col6" class="data row2 col6" >0.017384</td>
#       <td id="T_c26fd_row2_col7" class="data row2 col7" >0.083333</td>
#     </tr>
#     <tr>
#       <th id="T_c26fd_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_c26fd_row3_col0" class="data row3 col0" >0.000997</td>
#       <td id="T_c26fd_row3_col1" class="data row3 col1" >0.000997</td>
#       <td id="T_c26fd_row3_col2" class="data row3 col2" >0.002992</td>
#       <td id="T_c26fd_row3_col3" class="data row3 col3" >0.000998</td>
#       <td id="T_c26fd_row3_col4" class="data row3 col4" >8.281139</td>
#       <td id="T_c26fd_row3_col5" class="data row3 col5" >4.297872</td>
#       <td id="T_c26fd_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_c26fd_row3_col7" class="data row3 col7" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_reg', task='reg', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_88a32_row0_col0, #T_88a32_row0_col3, #T_88a32_row1_col0, #T_88a32_row1_col3, #T_88a32_row2_col0, #T_88a32_row2_col1, #T_88a32_row2_col2, #T_88a32_row2_col4, #T_88a32_row2_col5 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_88a32_row0_col1, #T_88a32_row0_col5, #T_88a32_row1_col2, #T_88a32_row1_col4, #T_88a32_row2_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_88a32_row0_col2 {
#   background-color: #cfe5cf;
#   color: #000000;
# }
# #T_88a32_row0_col4 {
#   background-color: #51a851;
#   color: #f1f1f1;
# }
# #T_88a32_row1_col1 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_88a32_row1_col5 {
#   background-color: #75b975;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_88a32_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >ANOVA</th>
#       <th class="col_heading level0 col2" >LGBM Imp.</th>
#       <th class="col_heading level0 col3" >PI mean</th>
#       <th class="col_heading level0 col4" >PI std</th>
#       <th class="col_heading level0 col5" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88a32_level0_row0" class="row_heading level0 row0" >c</th>
#       <td id="T_88a32_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_88a32_row0_col1" class="data row0 col1" >1.786485</td>
#       <td id="T_88a32_row0_col2" class="data row0 col2" >32.800000</td>
#       <td id="T_88a32_row0_col3" class="data row0 col3" >0.001761</td>
#       <td id="T_88a32_row0_col4" class="data row0 col4" >0.002304</td>
#       <td id="T_88a32_row0_col5" class="data row0 col5" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_88a32_level0_row1" class="row_heading level0 row1" >d</th>
#       <td id="T_88a32_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_88a32_row1_col1" class="data row1 col1" >0.044079</td>
#       <td id="T_88a32_row1_col2" class="data row1 col2" >265.500000</td>
#       <td id="T_88a32_row1_col3" class="data row1 col3" >-0.000106</td>
#       <td id="T_88a32_row1_col4" class="data row1 col4" >0.003522</td>
#       <td id="T_88a32_row1_col5" class="data row1 col5" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_88a32_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_88a32_row2_col0" class="data row2 col0" >0.000997</td>
#       <td id="T_88a32_row2_col1" class="data row2 col1" >0.001995</td>
#       <td id="T_88a32_row2_col2" class="data row2 col2" >1.568851</td>
#       <td id="T_88a32_row2_col3" class="data row2 col3" >2.419672</td>
#       <td id="T_88a32_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_88a32_row2_col5" class="data row2 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_clf_binary', task='clf_binary', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_fa5d9_row0_col0, #T_fa5d9_row0_col1, #T_fa5d9_row0_col3, #T_fa5d9_row0_col6, #T_fa5d9_row0_col7, #T_fa5d9_row1_col4, #T_fa5d9_row2_col5 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_fa5d9_row0_col2, #T_fa5d9_row1_col1, #T_fa5d9_row1_col2, #T_fa5d9_row1_col3, #T_fa5d9_row1_col5, #T_fa5d9_row1_col6, #T_fa5d9_row2_col0, #T_fa5d9_row2_col1, #T_fa5d9_row2_col2, #T_fa5d9_row2_col4, #T_fa5d9_row2_col6, #T_fa5d9_row2_col7 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_fa5d9_row0_col4 {
#   background-color: #399c39;
#   color: #f1f1f1;
# }
# #T_fa5d9_row0_col5 {
#   background-color: #bdddbd;
#   color: #000000;
# }
# #T_fa5d9_row1_col0 {
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_fa5d9_row1_col7 {
#   background-color: #b1d7b1;
#   color: #000000;
# }
# #T_fa5d9_row2_col3 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# </style>
# <table id="T_fa5d9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col1" >Chi_Square</th>
#       <th class="col_heading level0 col2" >ANOVA</th>
#       <th class="col_heading level0 col3" >MI Scores</th>
#       <th class="col_heading level0 col4" >LGBM Imp.</th>
#       <th class="col_heading level0 col5" >PI mean</th>
#       <th class="col_heading level0 col6" >PI std</th>
#       <th class="col_heading level0 col7" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa5d9_level0_row0" class="row_heading level0 row0" >c</th>
#       <td id="T_fa5d9_row0_col0" class="data row0 col0" >0.997998</td>
#       <td id="T_fa5d9_row0_col1" class="data row0 col1" >505.000000</td>
#       <td id="T_fa5d9_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_fa5d9_row0_col3" class="data row0 col3" >0.693597</td>
#       <td id="T_fa5d9_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_fa5d9_row0_col5" class="data row0 col5" >0.506371</td>
#       <td id="T_fa5d9_row0_col6" class="data row0 col6" >0.040616</td>
#       <td id="T_fa5d9_row0_col7" class="data row0 col7" >0.666667</td>
#     </tr>
#     <tr>
#       <th id="T_fa5d9_level0_row1" class="row_heading level0 row1" >d</th>
#       <td id="T_fa5d9_row1_col0" class="data row1 col0" >0.043699</td>
#       <td id="T_fa5d9_row1_col1" class="data row1 col1" >0.091792</td>
#       <td id="T_fa5d9_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_fa5d9_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_fa5d9_row1_col4" class="data row1 col4" >131.900000</td>
#       <td id="T_fa5d9_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_fa5d9_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_fa5d9_row1_col7" class="data row1 col7" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_fa5d9_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_fa5d9_row2_col0" class="data row2 col0" >0.014994</td>
#       <td id="T_fa5d9_row2_col1" class="data row2 col1" >0.003985</td>
#       <td id="T_fa5d9_row2_col2" class="data row2 col2" >0.000968</td>
#       <td id="T_fa5d9_row2_col3" class="data row2 col3" >0.017980</td>
#       <td id="T_fa5d9_row2_col4" class="data row2 col4" >1.050139</td>
#       <td id="T_fa5d9_row2_col5" class="data row2 col5" >2.630999</td>
#       <td id="T_fa5d9_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_fa5d9_row2_col7" class="data row2 col7" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_clf_multi', task='clf_multiable', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_b1f08_row0_col0, #T_b1f08_row0_col1, #T_b1f08_row0_col3, #T_b1f08_row0_col4, #T_b1f08_row0_col6, #T_b1f08_row0_col7, #T_b1f08_row2_col5 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_b1f08_row0_col2, #T_b1f08_row1_col1, #T_b1f08_row1_col2, #T_b1f08_row1_col3, #T_b1f08_row1_col5, #T_b1f08_row1_col6, #T_b1f08_row1_col7, #T_b1f08_row2_col0, #T_b1f08_row2_col1, #T_b1f08_row2_col2, #T_b1f08_row2_col4, #T_b1f08_row2_col6, #T_b1f08_row2_col7 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_b1f08_row0_col5 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_b1f08_row1_col0 {
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_b1f08_row1_col4 {
#   background-color: #92c892;
#   color: #000000;
# }
# #T_b1f08_row2_col3 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# </style>
# <table id="T_b1f08_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col1" >Chi_Square</th>
#       <th class="col_heading level0 col2" >ANOVA</th>
#       <th class="col_heading level0 col3" >MI Scores</th>
#       <th class="col_heading level0 col4" >LGBM Imp.</th>
#       <th class="col_heading level0 col5" >PI mean</th>
#       <th class="col_heading level0 col6" >PI std</th>
#       <th class="col_heading level0 col7" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1f08_level0_row0" class="row_heading level0 row0" >d</th>
#       <td id="T_b1f08_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b1f08_row0_col1" class="data row0 col1" >1735.007764</td>
#       <td id="T_b1f08_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_b1f08_row0_col3" class="data row0 col3" >2.300733</td>
#       <td id="T_b1f08_row0_col4" class="data row0 col4" >4021.000000</td>
#       <td id="T_b1f08_row0_col5" class="data row0 col5" >0.898291</td>
#       <td id="T_b1f08_row0_col6" class="data row0 col6" >0.022235</td>
#       <td id="T_b1f08_row0_col7" class="data row0 col7" >0.833333</td>
#     </tr>
#     <tr>
#       <th id="T_b1f08_level0_row1" class="row_heading level0 row1" >c</th>
#       <td id="T_b1f08_row1_col0" class="data row1 col0" >0.043699</td>
#       <td id="T_b1f08_row1_col1" class="data row1 col1" >5.512941</td>
#       <td id="T_b1f08_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_b1f08_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_b1f08_row1_col4" class="data row1 col4" >1510.800000</td>
#       <td id="T_b1f08_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_b1f08_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_b1f08_row1_col7" class="data row1 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b1f08_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_b1f08_row2_col0" class="data row2 col0" >0.015467</td>
#       <td id="T_b1f08_row2_col1" class="data row2 col1" >0.002992</td>
#       <td id="T_b1f08_row2_col2" class="data row2 col2" >0.000996</td>
#       <td id="T_b1f08_row2_col3" class="data row2 col3" >0.023937</td>
#       <td id="T_b1f08_row2_col4" class="data row2 col4" >3.131151</td>
#       <td id="T_b1f08_row2_col5" class="data row2 col5" >2.686418</td>
#       <td id="T_b1f08_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_b1f08_row2_col7" class="data row2 col7" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
