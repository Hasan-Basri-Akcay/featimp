# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sklearn.datasets import load_diabetes
from sklearn.preprocessing import OrdinalEncoder

from featimp import (
    get_corr_importances,
    get_chi2_crosstab_importances,
    get_chi2_importances,
    get_anova_importances,
    get_mutual_info_importances,
    get_ml_importances,
    get_permutation_importances,
    get_feature_importances,
    )

sns.set()
warnings.simplefilter("ignore")
cm = sns.color_palette("coolwarm", as_cmap=True)

# %%
column_a = np.random.rand(1, 1000)
column_b = np.random.rand(1, 1000)
column_c = np.random.randint(2, size=1000)
column_d = np.random.randint(10, size=1000)
column_e = np.random.normal(0, 1, size=1000)
test_df = pd.DataFrame()
test_df['a'] = column_a[0]
test_df['b'] = column_b[0]
test_df['c'] = column_c
test_df['d'] = column_d
test_df['e'] = column_e
test_df['target_reg'] = column_a[0]
test_df['target_clf_binary'] = column_c
test_df['target_clf_multi'] = column_d
display(test_df.head())
# Out:
#           a         b  c  d         e  target_reg  target_clf_binary  \
# 0  0.300411  0.220093  1  5  0.085985    0.300411                  1
# 1  0.040481  0.509388  0  0  0.013116    0.040481                  0
# 2  0.209462  0.882535  1  7 -0.271098    0.209462                  1
# 3  0.660870  0.435131  1  9 -0.426930    0.660870                  1
# 4  0.823329  0.842754  1  2 -0.865616    0.823329                  1
#
#    target_clf_multi
# 0                 5
# 1                 0
# 2                 7
# 3                 9
# 4                 2

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_reg', task='reg', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_ead90_row0_col0, #T_ead90_row0_col2, #T_ead90_row0_col4, #T_ead90_row0_col5, #T_ead90_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ead90_row0_col1, #T_ead90_row1_col1, #T_ead90_row1_col3, #T_ead90_row1_col4, #T_ead90_row2_col0, #T_ead90_row2_col1, #T_ead90_row2_col3, #T_ead90_row2_col4, #T_ead90_row2_col5, #T_ead90_row3_col0, #T_ead90_row3_col1, #T_ead90_row3_col2, #T_ead90_row3_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ead90_row0_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_ead90_row1_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_ead90_row1_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_ead90_row1_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ead90_row2_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_ead90_row3_col5 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# </style>
# <table id="T_ead90_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >ANOVA</th>
#       <th class="col_heading level0 col2" >LGBM Imp.</th>
#       <th class="col_heading level0 col3" >PI mean</th>
#       <th class="col_heading level0 col4" >PI std</th>
#       <th class="col_heading level0 col5" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ead90_level0_row0" class="row_heading level0 row0" >a</th>
#       <td id="T_ead90_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ead90_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_ead90_row0_col2" class="data row0 col2" >1492.400000</td>
#       <td id="T_ead90_row0_col3" class="data row0 col3" >0.393233</td>
#       <td id="T_ead90_row0_col4" class="data row0 col4" >0.021121</td>
#       <td id="T_ead90_row0_col5" class="data row0 col5" >1.060386</td>
#     </tr>
#     <tr>
#       <th id="T_ead90_level0_row1" class="row_heading level0 row1" >b</th>
#       <td id="T_ead90_row1_col0" class="data row1 col0" >0.050035</td>
#       <td id="T_ead90_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_ead90_row1_col2" class="data row1 col2" >304.400000</td>
#       <td id="T_ead90_row1_col3" class="data row1 col3" >-0.000004</td>
#       <td id="T_ead90_row1_col4" class="data row1 col4" >0.000014</td>
#       <td id="T_ead90_row1_col5" class="data row1 col5" >-0.518230</td>
#     </tr>
#     <tr>
#       <th id="T_ead90_level0_row2" class="row_heading level0 row2" >e</th>
#       <td id="T_ead90_row2_col0" class="data row2 col0" >0.005785</td>
#       <td id="T_ead90_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_ead90_row2_col2" class="data row2 col2" >304.800000</td>
#       <td id="T_ead90_row2_col3" class="data row2 col3" >0.000009</td>
#       <td id="T_ead90_row2_col4" class="data row2 col4" >0.000019</td>
#       <td id="T_ead90_row2_col5" class="data row2 col5" >-0.542156</td>
#     </tr>
#     <tr>
#       <th id="T_ead90_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_ead90_row3_col0" class="data row3 col0" >0.003989</td>
#       <td id="T_ead90_row3_col1" class="data row3 col1" >0.000997</td>
#       <td id="T_ead90_row3_col2" class="data row3 col2" >1.990180</td>
#       <td id="T_ead90_row3_col3" class="data row3 col3" >4.596878</td>
#       <td id="T_ead90_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_ead90_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_clf_binary', task='clf_binary', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_d5d19_row0_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_d5d19_row0_col1, #T_d5d19_row0_col2, #T_d5d19_row0_col4, #T_d5d19_row1_col1, #T_d5d19_row1_col2, #T_d5d19_row1_col4, #T_d5d19_row1_col6, #T_d5d19_row2_col1, #T_d5d19_row2_col2, #T_d5d19_row2_col4, #T_d5d19_row2_col6, #T_d5d19_row2_col8, #T_d5d19_row3_col0, #T_d5d19_row3_col1, #T_d5d19_row3_col2, #T_d5d19_row3_col3, #T_d5d19_row3_col4, #T_d5d19_row3_col5, #T_d5d19_row3_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d5d19_row0_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_d5d19_row0_col5 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_d5d19_row0_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_d5d19_row0_col7 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_d5d19_row0_col8, #T_d5d19_row1_col0, #T_d5d19_row1_col3, #T_d5d19_row2_col5, #T_d5d19_row2_col7, #T_d5d19_row3_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d5d19_row1_col5, #T_d5d19_row1_col7 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_d5d19_row1_col8 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_d5d19_row2_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_d5d19_row2_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_d5d19_row3_col8 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# </style>
# <table id="T_d5d19_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col2" >Chi_Square</th>
#       <th class="col_heading level0 col3" >ANOVA</th>
#       <th class="col_heading level0 col4" >MI Scores</th>
#       <th class="col_heading level0 col5" >LGBM Imp.</th>
#       <th class="col_heading level0 col6" >PI mean</th>
#       <th class="col_heading level0 col7" >PI std</th>
#       <th class="col_heading level0 col8" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5d19_level0_row0" class="row_heading level0 row0" >a</th>
#       <td id="T_d5d19_row0_col0" class="data row0 col0" >0.022192</td>
#       <td id="T_d5d19_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_d5d19_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_d5d19_row0_col3" class="data row0 col3" >0.491721</td>
#       <td id="T_d5d19_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_d5d19_row0_col5" class="data row0 col5" >45.100000</td>
#       <td id="T_d5d19_row0_col6" class="data row0 col6" >0.028281</td>
#       <td id="T_d5d19_row0_col7" class="data row0 col7" >0.032722</td>
#       <td id="T_d5d19_row0_col8" class="data row0 col8" >0.182797</td>
#     </tr>
#     <tr>
#       <th id="T_d5d19_level0_row1" class="row_heading level0 row1" >e</th>
#       <td id="T_d5d19_row1_col0" class="data row1 col0" >0.046069</td>
#       <td id="T_d5d19_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_d5d19_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_d5d19_row1_col3" class="data row1 col3" >2.122585</td>
#       <td id="T_d5d19_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_d5d19_row1_col5" class="data row1 col5" >41.600000</td>
#       <td id="T_d5d19_row1_col6" class="data row1 col6" >0.004398</td>
#       <td id="T_d5d19_row1_col7" class="data row1 col7" >0.037729</td>
#       <td id="T_d5d19_row1_col8" class="data row1 col8" >0.148323</td>
#     </tr>
#     <tr>
#       <th id="T_d5d19_level0_row2" class="row_heading level0 row2" >b</th>
#       <td id="T_d5d19_row2_col0" class="data row2 col0" >0.009268</td>
#       <td id="T_d5d19_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_d5d19_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_d5d19_row2_col3" class="data row2 col3" >0.085735</td>
#       <td id="T_d5d19_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_d5d19_row2_col5" class="data row2 col5" >45.300000</td>
#       <td id="T_d5d19_row2_col6" class="data row2 col6" >-0.007626</td>
#       <td id="T_d5d19_row2_col7" class="data row2 col7" >0.041183</td>
#       <td id="T_d5d19_row2_col8" class="data row2 col8" >-0.331120</td>
#     </tr>
#     <tr>
#       <th id="T_d5d19_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_d5d19_row3_col0" class="data row3 col0" >0.001994</td>
#       <td id="T_d5d19_row3_col1" class="data row3 col1" >0.001995</td>
#       <td id="T_d5d19_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_d5d19_row3_col3" class="data row3 col3" >0.003991</td>
#       <td id="T_d5d19_row3_col4" class="data row3 col4" >0.000996</td>
#       <td id="T_d5d19_row3_col5" class="data row3 col5" >1.897536</td>
#       <td id="T_d5d19_row3_col6" class="data row3 col6" >4.301232</td>
#       <td id="T_d5d19_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_d5d19_row3_col8" class="data row3 col8" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_clf_multi', task='clf_multiable', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_8a2ed_row0_col0, #T_8a2ed_row0_col1, #T_8a2ed_row0_col2, #T_8a2ed_row0_col4, #T_8a2ed_row0_col6, #T_8a2ed_row1_col0, #T_8a2ed_row1_col1, #T_8a2ed_row1_col2, #T_8a2ed_row1_col4, #T_8a2ed_row1_col6, #T_8a2ed_row2_col0, #T_8a2ed_row2_col1, #T_8a2ed_row2_col2, #T_8a2ed_row2_col4, #T_8a2ed_row2_col6, #T_8a2ed_row2_col8, #T_8a2ed_row3_col0, #T_8a2ed_row3_col1, #T_8a2ed_row3_col2, #T_8a2ed_row3_col3, #T_8a2ed_row3_col4, #T_8a2ed_row3_col5, #T_8a2ed_row3_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8a2ed_row0_col3 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_8a2ed_row0_col5, #T_8a2ed_row0_col8, #T_8a2ed_row1_col3, #T_8a2ed_row1_col7, #T_8a2ed_row3_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8a2ed_row0_col7 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_8a2ed_row1_col5 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_8a2ed_row1_col8 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_8a2ed_row2_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_8a2ed_row2_col5 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_8a2ed_row2_col7 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_8a2ed_row3_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# </style>
# <table id="T_8a2ed_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col2" >Chi_Square</th>
#       <th class="col_heading level0 col3" >ANOVA</th>
#       <th class="col_heading level0 col4" >MI Scores</th>
#       <th class="col_heading level0 col5" >LGBM Imp.</th>
#       <th class="col_heading level0 col6" >PI mean</th>
#       <th class="col_heading level0 col7" >PI std</th>
#       <th class="col_heading level0 col8" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a2ed_level0_row0" class="row_heading level0 row0" >b</th>
#       <td id="T_8a2ed_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_8a2ed_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_8a2ed_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_8a2ed_row0_col3" class="data row0 col3" >1.024484</td>
#       <td id="T_8a2ed_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_8a2ed_row0_col5" class="data row0 col5" >121.300000</td>
#       <td id="T_8a2ed_row0_col6" class="data row0 col6" >0.009054</td>
#       <td id="T_8a2ed_row0_col7" class="data row0 col7" >0.021862</td>
#       <td id="T_8a2ed_row0_col8" class="data row0 col8" >0.149339</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ed_level0_row1" class="row_heading level0 row1" >e</th>
#       <td id="T_8a2ed_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_8a2ed_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_8a2ed_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_8a2ed_row1_col3" class="data row1 col3" >1.683552</td>
#       <td id="T_8a2ed_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_8a2ed_row1_col5" class="data row1 col5" >118.100000</td>
#       <td id="T_8a2ed_row1_col6" class="data row1 col6" >0.007548</td>
#       <td id="T_8a2ed_row1_col7" class="data row1 col7" >0.025329</td>
#       <td id="T_8a2ed_row1_col8" class="data row1 col8" >0.006013</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ed_level0_row2" class="row_heading level0 row2" >a</th>
#       <td id="T_8a2ed_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_8a2ed_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_8a2ed_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_8a2ed_row2_col3" class="data row2 col3" >0.021205</td>
#       <td id="T_8a2ed_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_8a2ed_row2_col5" class="data row2 col5" >115.700000</td>
#       <td id="T_8a2ed_row2_col6" class="data row2 col6" >0.013726</td>
#       <td id="T_8a2ed_row2_col7" class="data row2 col7" >0.018575</td>
#       <td id="T_8a2ed_row2_col8" class="data row2 col8" >-0.155352</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ed_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_8a2ed_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_8a2ed_row3_col1" class="data row3 col1" >0.000996</td>
#       <td id="T_8a2ed_row3_col2" class="data row3 col2" >0.000997</td>
#       <td id="T_8a2ed_row3_col3" class="data row3 col3" >0.001995</td>
#       <td id="T_8a2ed_row3_col4" class="data row3 col4" >0.001994</td>
#       <td id="T_8a2ed_row3_col5" class="data row3 col5" >8.457257</td>
#       <td id="T_8a2ed_row3_col6" class="data row3 col6" >4.827351</td>
#       <td id="T_8a2ed_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_8a2ed_row3_col8" class="data row3 col8" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_reg', task='reg', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_7d67c_row0_col0, #T_7d67c_row0_col3, #T_7d67c_row1_col0, #T_7d67c_row1_col3, #T_7d67c_row1_col5, #T_7d67c_row2_col0, #T_7d67c_row2_col1, #T_7d67c_row2_col2, #T_7d67c_row2_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7d67c_row0_col1, #T_7d67c_row0_col5, #T_7d67c_row1_col2, #T_7d67c_row1_col4, #T_7d67c_row2_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7d67c_row0_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_7d67c_row0_col4 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_7d67c_row1_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_7d67c_row2_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# </style>
# <table id="T_7d67c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >ANOVA</th>
#       <th class="col_heading level0 col2" >LGBM Imp.</th>
#       <th class="col_heading level0 col3" >PI mean</th>
#       <th class="col_heading level0 col4" >PI std</th>
#       <th class="col_heading level0 col5" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d67c_level0_row0" class="row_heading level0 row0" >c</th>
#       <td id="T_7d67c_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_7d67c_row0_col1" class="data row0 col1" >0.491721</td>
#       <td id="T_7d67c_row0_col2" class="data row0 col2" >5.400000</td>
#       <td id="T_7d67c_row0_col3" class="data row0 col3" >-0.001515</td>
#       <td id="T_7d67c_row0_col4" class="data row0 col4" >0.001706</td>
#       <td id="T_7d67c_row0_col5" class="data row0 col5" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_7d67c_level0_row1" class="row_heading level0 row1" >d</th>
#       <td id="T_7d67c_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_7d67c_row1_col1" class="data row1 col1" >0.021205</td>
#       <td id="T_7d67c_row1_col2" class="data row1 col2" >13.600000</td>
#       <td id="T_7d67c_row1_col3" class="data row1 col3" >-0.002208</td>
#       <td id="T_7d67c_row1_col4" class="data row1 col4" >0.002750</td>
#       <td id="T_7d67c_row1_col5" class="data row1 col5" >-0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_7d67c_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_7d67c_row2_col0" class="data row2 col0" >0.000996</td>
#       <td id="T_7d67c_row2_col1" class="data row2 col1" >0.003990</td>
#       <td id="T_7d67c_row2_col2" class="data row2 col2" >1.570452</td>
#       <td id="T_7d67c_row2_col3" class="data row2 col3" >2.653058</td>
#       <td id="T_7d67c_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_7d67c_row2_col5" class="data row2 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_clf_binary', task='clf_binary', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_66828_row0_col0, #T_66828_row0_col3, #T_66828_row1_col0, #T_66828_row1_col1, #T_66828_row1_col2, #T_66828_row1_col3, #T_66828_row1_col4, #T_66828_row1_col6, #T_66828_row1_col7, #T_66828_row1_col8, #T_66828_row2_col0, #T_66828_row2_col2, #T_66828_row2_col3, #T_66828_row2_col5, #T_66828_row2_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_66828_row0_col1, #T_66828_row0_col2, #T_66828_row0_col4, #T_66828_row0_col7, #T_66828_row0_col8, #T_66828_row1_col5, #T_66828_row2_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_66828_row0_col5 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_66828_row0_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_66828_row2_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_66828_row2_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_66828_row2_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_66828_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col2" >Chi_Square</th>
#       <th class="col_heading level0 col3" >ANOVA</th>
#       <th class="col_heading level0 col4" >MI Scores</th>
#       <th class="col_heading level0 col5" >LGBM Imp.</th>
#       <th class="col_heading level0 col6" >PI mean</th>
#       <th class="col_heading level0 col7" >PI std</th>
#       <th class="col_heading level0 col8" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66828_level0_row0" class="row_heading level0 row0" >c</th>
#       <td id="T_66828_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_66828_row0_col1" class="data row0 col1" >0.997998</td>
#       <td id="T_66828_row0_col2" class="data row0 col2" >502.000000</td>
#       <td id="T_66828_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_66828_row0_col4" class="data row0 col4" >0.693639</td>
#       <td id="T_66828_row0_col5" class="data row0 col5" >100.000000</td>
#       <td id="T_66828_row0_col6" class="data row0 col6" >0.498531</td>
#       <td id="T_66828_row0_col7" class="data row0 col7" >0.034853</td>
#       <td id="T_66828_row0_col8" class="data row0 col8" >0.428571</td>
#     </tr>
#     <tr>
#       <th id="T_66828_level0_row1" class="row_heading level0 row1" >d</th>
#       <td id="T_66828_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_66828_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_66828_row1_col2" class="data row1 col2" >1.915530</td>
#       <td id="T_66828_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_66828_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_66828_row1_col5" class="data row1 col5" >135.400000</td>
#       <td id="T_66828_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_66828_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_66828_row1_col8" class="data row1 col8" >-0.428571</td>
#     </tr>
#     <tr>
#       <th id="T_66828_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_66828_row2_col0" class="data row2 col0" >0.000997</td>
#       <td id="T_66828_row2_col1" class="data row2 col1" >0.016955</td>
#       <td id="T_66828_row2_col2" class="data row2 col2" >0.002992</td>
#       <td id="T_66828_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_66828_row2_col4" class="data row2 col4" >0.018951</td>
#       <td id="T_66828_row2_col5" class="data row2 col5" >1.135264</td>
#       <td id="T_66828_row2_col6" class="data row2 col6" >2.804811</td>
#       <td id="T_66828_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_66828_row2_col8" class="data row2 col8" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_clf_multi', task='clf_multiable', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_86dea_row0_col0, #T_86dea_row0_col3, #T_86dea_row1_col0, #T_86dea_row1_col1, #T_86dea_row1_col2, #T_86dea_row1_col3, #T_86dea_row1_col4, #T_86dea_row1_col6, #T_86dea_row1_col7, #T_86dea_row1_col8, #T_86dea_row2_col0, #T_86dea_row2_col2, #T_86dea_row2_col3, #T_86dea_row2_col5, #T_86dea_row2_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_86dea_row0_col1, #T_86dea_row0_col2, #T_86dea_row0_col4, #T_86dea_row0_col5, #T_86dea_row0_col7, #T_86dea_row0_col8, #T_86dea_row2_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_86dea_row0_col6 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_86dea_row1_col5 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_86dea_row2_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_86dea_row2_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_86dea_row2_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_86dea_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col2" >Chi_Square</th>
#       <th class="col_heading level0 col3" >ANOVA</th>
#       <th class="col_heading level0 col4" >MI Scores</th>
#       <th class="col_heading level0 col5" >LGBM Imp.</th>
#       <th class="col_heading level0 col6" >PI mean</th>
#       <th class="col_heading level0 col7" >PI std</th>
#       <th class="col_heading level0 col8" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86dea_level0_row0" class="row_heading level0 row0" >d</th>
#       <td id="T_86dea_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_86dea_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_86dea_row0_col2" class="data row0 col2" >1841.250055</td>
#       <td id="T_86dea_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_86dea_row0_col4" class="data row0 col4" >2.303580</td>
#       <td id="T_86dea_row0_col5" class="data row0 col5" >4114.900000</td>
#       <td id="T_86dea_row0_col6" class="data row0 col6" >0.904020</td>
#       <td id="T_86dea_row0_col7" class="data row0 col7" >0.025041</td>
#       <td id="T_86dea_row0_col8" class="data row0 col8" >0.714286</td>
#     </tr>
#     <tr>
#       <th id="T_86dea_level0_row1" class="row_heading level0 row1" >c</th>
#       <td id="T_86dea_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_86dea_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_86dea_row1_col2" class="data row1 col2" >3.872335</td>
#       <td id="T_86dea_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_86dea_row1_col4" class="data row1 col4" >0.010254</td>
#       <td id="T_86dea_row1_col5" class="data row1 col5" >1708.300000</td>
#       <td id="T_86dea_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_86dea_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_86dea_row1_col8" class="data row1 col8" >-0.714286</td>
#     </tr>
#     <tr>
#       <th id="T_86dea_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_86dea_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_86dea_row2_col1" class="data row2 col1" >0.017951</td>
#       <td id="T_86dea_row2_col2" class="data row2 col2" >0.002994</td>
#       <td id="T_86dea_row2_col3" class="data row2 col3" >0.000997</td>
#       <td id="T_86dea_row2_col4" class="data row2 col4" >0.023948</td>
#       <td id="T_86dea_row2_col5" class="data row2 col5" >3.126704</td>
#       <td id="T_86dea_row2_col6" class="data row2 col6" >2.947004</td>
#       <td id="T_86dea_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_86dea_row2_col8" class="data row2 col8" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
