# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sklearn.datasets import load_diabetes
from sklearn.preprocessing import OrdinalEncoder

from featimp import (
    get_corr_importances,
    get_chi2_crosstab_importances,
    get_chi2_importances,
    get_anova_importances,
    get_mutual_info_importances,
    get_ml_importances,
    get_permutation_importances,
    get_feature_importances,
    )

sns.set()
warnings.simplefilter("ignore")
cm = sns.color_palette("coolwarm", as_cmap=True)

# %%
column_a = np.random.rand(1, 1000)
column_b = np.random.rand(1, 1000)
column_c = np.random.randint(2, size=1000)
column_d = np.random.randint(10, size=1000)
column_e = np.random.normal(0, 1, size=1000)
test_df = pd.DataFrame()
test_df['a'] = column_a[0]
test_df['b'] = column_b[0]
test_df['c'] = column_c
test_df['d'] = column_d
test_df['e'] = column_e
test_df['target_reg'] = column_a[0]
test_df['target_clf_binary'] = column_c
test_df['target_clf_multi'] = column_d
display(test_df.head())
# Out:
#           a         b  c  d         e  target_reg  target_clf_binary  \
# 0  0.318193  0.148688  0  3  1.292850    0.318193                  0
# 1  0.861488  0.672608  0  0 -2.008093    0.861488                  0
# 2  0.391809  0.935112  0  0  0.358809    0.391809                  0
# 3  0.929718  0.190643  0  4  0.461655    0.929718                  0
# 4  0.847229  0.622950  1  2 -0.252416    0.847229                  1
#
#    target_clf_multi
# 0                 3
# 1                 0
# 2                 0
# 3                 4
# 4                 2

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_reg', task='reg', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_e0f7f_row0_col0, #T_e0f7f_row0_col2, #T_e0f7f_row0_col4, #T_e0f7f_row0_col5, #T_e0f7f_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e0f7f_row0_col1, #T_e0f7f_row1_col1, #T_e0f7f_row1_col3, #T_e0f7f_row1_col4, #T_e0f7f_row1_col5, #T_e0f7f_row2_col1, #T_e0f7f_row2_col3, #T_e0f7f_row2_col4, #T_e0f7f_row2_col5, #T_e0f7f_row3_col0, #T_e0f7f_row3_col1, #T_e0f7f_row3_col2, #T_e0f7f_row3_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e0f7f_row0_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_e0f7f_row1_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_e0f7f_row1_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e0f7f_row2_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e0f7f_row2_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e0f7f_row3_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# </style>
# <table id="T_e0f7f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >ANOVA</th>
#       <th class="col_heading level0 col2" >LGBM Imp.</th>
#       <th class="col_heading level0 col3" >PI mean</th>
#       <th class="col_heading level0 col4" >PI std</th>
#       <th class="col_heading level0 col5" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0f7f_level0_row0" class="row_heading level0 row0" >a</th>
#       <td id="T_e0f7f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e0f7f_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_e0f7f_row0_col2" class="data row0 col2" >1537.500000</td>
#       <td id="T_e0f7f_row0_col3" class="data row0 col3" >0.406731</td>
#       <td id="T_e0f7f_row0_col4" class="data row0 col4" >0.018129</td>
#       <td id="T_e0f7f_row0_col5" class="data row0 col5" >1.060590</td>
#     </tr>
#     <tr>
#       <th id="T_e0f7f_level0_row1" class="row_heading level0 row1" >e</th>
#       <td id="T_e0f7f_row1_col0" class="data row1 col0" >0.018988</td>
#       <td id="T_e0f7f_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_e0f7f_row1_col2" class="data row1 col2" >378.400000</td>
#       <td id="T_e0f7f_row1_col3" class="data row1 col3" >-0.000006</td>
#       <td id="T_e0f7f_row1_col4" class="data row1 col4" >0.000017</td>
#       <td id="T_e0f7f_row1_col5" class="data row1 col5" >-0.527733</td>
#     </tr>
#     <tr>
#       <th id="T_e0f7f_level0_row2" class="row_heading level0 row2" >b</th>
#       <td id="T_e0f7f_row2_col0" class="data row2 col0" >0.029471</td>
#       <td id="T_e0f7f_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_e0f7f_row2_col2" class="data row2 col2" >354.500000</td>
#       <td id="T_e0f7f_row2_col3" class="data row2 col3" >-0.000006</td>
#       <td id="T_e0f7f_row2_col4" class="data row2 col4" >0.000015</td>
#       <td id="T_e0f7f_row2_col5" class="data row2 col5" >-0.532857</td>
#     </tr>
#     <tr>
#       <th id="T_e0f7f_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_e0f7f_row3_col0" class="data row3 col0" >0.002992</td>
#       <td id="T_e0f7f_row3_col1" class="data row3 col1" >0.002991</td>
#       <td id="T_e0f7f_row3_col2" class="data row3 col2" >1.658564</td>
#       <td id="T_e0f7f_row3_col3" class="data row3 col3" >3.911203</td>
#       <td id="T_e0f7f_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_e0f7f_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_clf_binary', task='clf_binary', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_f21c4_row0_col0, #T_f21c4_row0_col1, #T_f21c4_row0_col3, #T_f21c4_row0_col5, #T_f21c4_row1_col0, #T_f21c4_row1_col1, #T_f21c4_row1_col3, #T_f21c4_row1_col5, #T_f21c4_row2_col0, #T_f21c4_row2_col1, #T_f21c4_row2_col3, #T_f21c4_row2_col5, #T_f21c4_row2_col7, #T_f21c4_row3_col0, #T_f21c4_row3_col1, #T_f21c4_row3_col2, #T_f21c4_row3_col3, #T_f21c4_row3_col4, #T_f21c4_row3_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f21c4_row0_col2, #T_f21c4_row0_col4, #T_f21c4_row0_col6, #T_f21c4_row0_col7, #T_f21c4_row3_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f21c4_row1_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_f21c4_row1_col4 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_f21c4_row1_col6 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_f21c4_row1_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_f21c4_row2_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_f21c4_row2_col4 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_f21c4_row2_col6 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_f21c4_row3_col7 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# </style>
# <table id="T_f21c4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col1" >Chi_Square</th>
#       <th class="col_heading level0 col2" >ANOVA</th>
#       <th class="col_heading level0 col3" >MI Scores</th>
#       <th class="col_heading level0 col4" >LGBM Imp.</th>
#       <th class="col_heading level0 col5" >PI mean</th>
#       <th class="col_heading level0 col6" >PI std</th>
#       <th class="col_heading level0 col7" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f21c4_level0_row0" class="row_heading level0 row0" >e</th>
#       <td id="T_f21c4_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_f21c4_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_f21c4_row0_col2" class="data row0 col2" >3.976553</td>
#       <td id="T_f21c4_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_f21c4_row0_col4" class="data row0 col4" >51.900000</td>
#       <td id="T_f21c4_row0_col5" class="data row0 col5" >0.011161</td>
#       <td id="T_f21c4_row0_col6" class="data row0 col6" >0.041971</td>
#       <td id="T_f21c4_row0_col7" class="data row0 col7" >0.635973</td>
#     </tr>
#     <tr>
#       <th id="T_f21c4_level0_row1" class="row_heading level0 row1" >b</th>
#       <td id="T_f21c4_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_f21c4_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_f21c4_row1_col2" class="data row1 col2" >1.181028</td>
#       <td id="T_f21c4_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_f21c4_row1_col4" class="data row1 col4" >51.000000</td>
#       <td id="T_f21c4_row1_col5" class="data row1 col5" >0.006469</td>
#       <td id="T_f21c4_row1_col6" class="data row1 col6" >0.036776</td>
#       <td id="T_f21c4_row1_col7" class="data row1 col7" >-0.062933</td>
#     </tr>
#     <tr>
#       <th id="T_f21c4_level0_row2" class="row_heading level0 row2" >a</th>
#       <td id="T_f21c4_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_f21c4_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_f21c4_row2_col2" class="data row2 col2" >0.236873</td>
#       <td id="T_f21c4_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_f21c4_row2_col4" class="data row2 col4" >50.100000</td>
#       <td id="T_f21c4_row2_col5" class="data row2 col5" >0.001648</td>
#       <td id="T_f21c4_row2_col6" class="data row2 col6" >0.033719</td>
#       <td id="T_f21c4_row2_col7" class="data row2 col7" >-0.573040</td>
#     </tr>
#     <tr>
#       <th id="T_f21c4_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_f21c4_row3_col0" class="data row3 col0" >0.000997</td>
#       <td id="T_f21c4_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_f21c4_row3_col2" class="data row3 col2" >0.002991</td>
#       <td id="T_f21c4_row3_col3" class="data row3 col3" >0.001995</td>
#       <td id="T_f21c4_row3_col4" class="data row3 col4" >1.741374</td>
#       <td id="T_f21c4_row3_col5" class="data row3 col5" >3.922886</td>
#       <td id="T_f21c4_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_f21c4_row3_col7" class="data row3 col7" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=['a', 'b', 'e'], cat_features=[], target='target_clf_multi', task='clf_multiable', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_acad9_row0_col0, #T_acad9_row0_col1, #T_acad9_row0_col3, #T_acad9_row0_col5, #T_acad9_row1_col0, #T_acad9_row1_col1, #T_acad9_row1_col3, #T_acad9_row1_col5, #T_acad9_row2_col0, #T_acad9_row2_col1, #T_acad9_row2_col3, #T_acad9_row2_col5, #T_acad9_row2_col7, #T_acad9_row3_col0, #T_acad9_row3_col1, #T_acad9_row3_col2, #T_acad9_row3_col3, #T_acad9_row3_col4, #T_acad9_row3_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_acad9_row0_col2 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_acad9_row0_col4, #T_acad9_row0_col7, #T_acad9_row1_col2, #T_acad9_row2_col6, #T_acad9_row3_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_acad9_row0_col6 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_acad9_row1_col4 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_acad9_row1_col6 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_acad9_row1_col7 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_acad9_row2_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_acad9_row2_col4 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_acad9_row3_col7 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# </style>
# <table id="T_acad9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col1" >Chi_Square</th>
#       <th class="col_heading level0 col2" >ANOVA</th>
#       <th class="col_heading level0 col3" >MI Scores</th>
#       <th class="col_heading level0 col4" >LGBM Imp.</th>
#       <th class="col_heading level0 col5" >PI mean</th>
#       <th class="col_heading level0 col6" >PI std</th>
#       <th class="col_heading level0 col7" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acad9_level0_row0" class="row_heading level0 row0" >a</th>
#       <td id="T_acad9_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_acad9_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_acad9_row0_col2" class="data row0 col2" >0.449192</td>
#       <td id="T_acad9_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_acad9_row0_col4" class="data row0 col4" >104.600000</td>
#       <td id="T_acad9_row0_col5" class="data row0 col5" >-0.004962</td>
#       <td id="T_acad9_row0_col6" class="data row0 col6" >0.024948</td>
#       <td id="T_acad9_row0_col7" class="data row0 col7" >0.331818</td>
#     </tr>
#     <tr>
#       <th id="T_acad9_level0_row1" class="row_heading level0 row1" >b</th>
#       <td id="T_acad9_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_acad9_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_acad9_row1_col2" class="data row1 col2" >0.509924</td>
#       <td id="T_acad9_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_acad9_row1_col4" class="data row1 col4" >96.300000</td>
#       <td id="T_acad9_row1_col5" class="data row1 col5" >-0.001225</td>
#       <td id="T_acad9_row1_col6" class="data row1 col6" >0.023351</td>
#       <td id="T_acad9_row1_col7" class="data row1 col7" >0.270762</td>
#     </tr>
#     <tr>
#       <th id="T_acad9_level0_row2" class="row_heading level0 row2" >e</th>
#       <td id="T_acad9_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_acad9_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_acad9_row2_col2" class="data row2 col2" >0.161421</td>
#       <td id="T_acad9_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_acad9_row2_col4" class="data row2 col4" >94.000000</td>
#       <td id="T_acad9_row2_col5" class="data row2 col5" >-0.009858</td>
#       <td id="T_acad9_row2_col6" class="data row2 col6" >0.025939</td>
#       <td id="T_acad9_row2_col7" class="data row2 col7" >-0.602580</td>
#     </tr>
#     <tr>
#       <th id="T_acad9_level0_row3" class="row_heading level0 row3" >TT (Sec)</th>
#       <td id="T_acad9_row3_col0" class="data row3 col0" >0.000998</td>
#       <td id="T_acad9_row3_col1" class="data row3 col1" >0.000997</td>
#       <td id="T_acad9_row3_col2" class="data row3 col2" >0.002991</td>
#       <td id="T_acad9_row3_col3" class="data row3 col3" >0.000998</td>
#       <td id="T_acad9_row3_col4" class="data row3 col4" >7.946371</td>
#       <td id="T_acad9_row3_col5" class="data row3 col5" >4.137604</td>
#       <td id="T_acad9_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_acad9_row3_col7" class="data row3 col7" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_reg', task='reg', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_aa621_row0_col0, #T_aa621_row0_col3, #T_aa621_row1_col0, #T_aa621_row1_col3, #T_aa621_row1_col5, #T_aa621_row2_col0, #T_aa621_row2_col1, #T_aa621_row2_col2, #T_aa621_row2_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_aa621_row0_col1, #T_aa621_row0_col2, #T_aa621_row0_col4, #T_aa621_row0_col5, #T_aa621_row2_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_aa621_row1_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_aa621_row1_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_aa621_row1_col4 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_aa621_row2_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_aa621_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Corr</th>
#       <th class="col_heading level0 col1" >ANOVA</th>
#       <th class="col_heading level0 col2" >LGBM Imp.</th>
#       <th class="col_heading level0 col3" >PI mean</th>
#       <th class="col_heading level0 col4" >PI std</th>
#       <th class="col_heading level0 col5" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa621_level0_row0" class="row_heading level0 row0" >d</th>
#       <td id="T_aa621_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_aa621_row0_col1" class="data row0 col1" >0.449192</td>
#       <td id="T_aa621_row0_col2" class="data row0 col2" >88.400000</td>
#       <td id="T_aa621_row0_col3" class="data row0 col3" >0.000665</td>
#       <td id="T_aa621_row0_col4" class="data row0 col4" >0.003607</td>
#       <td id="T_aa621_row0_col5" class="data row0 col5" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_aa621_level0_row1" class="row_heading level0 row1" >c</th>
#       <td id="T_aa621_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_aa621_row1_col1" class="data row1 col1" >0.236873</td>
#       <td id="T_aa621_row1_col2" class="data row1 col2" >31.300000</td>
#       <td id="T_aa621_row1_col3" class="data row1 col3" >0.001430</td>
#       <td id="T_aa621_row1_col4" class="data row1 col4" >0.002555</td>
#       <td id="T_aa621_row1_col5" class="data row1 col5" >-0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_aa621_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_aa621_row2_col0" class="data row2 col0" >0.000997</td>
#       <td id="T_aa621_row2_col1" class="data row2 col1" >0.002992</td>
#       <td id="T_aa621_row2_col2" class="data row2 col2" >1.315620</td>
#       <td id="T_aa621_row2_col3" class="data row2 col3" >2.262519</td>
#       <td id="T_aa621_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_aa621_row2_col5" class="data row2 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_clf_binary', task='clf_binary', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_7df3f_row0_col0, #T_7df3f_row0_col1, #T_7df3f_row0_col3, #T_7df3f_row0_col6, #T_7df3f_row0_col7, #T_7df3f_row1_col4, #T_7df3f_row2_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7df3f_row0_col2, #T_7df3f_row1_col0, #T_7df3f_row1_col1, #T_7df3f_row1_col2, #T_7df3f_row1_col5, #T_7df3f_row1_col6, #T_7df3f_row1_col7, #T_7df3f_row2_col1, #T_7df3f_row2_col2, #T_7df3f_row2_col3, #T_7df3f_row2_col4, #T_7df3f_row2_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7df3f_row0_col4 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_7df3f_row0_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_7df3f_row1_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_7df3f_row2_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_7df3f_row2_col7 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_7df3f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col1" >Chi_Square</th>
#       <th class="col_heading level0 col2" >ANOVA</th>
#       <th class="col_heading level0 col3" >MI Scores</th>
#       <th class="col_heading level0 col4" >LGBM Imp.</th>
#       <th class="col_heading level0 col5" >PI mean</th>
#       <th class="col_heading level0 col6" >PI std</th>
#       <th class="col_heading level0 col7" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7df3f_level0_row0" class="row_heading level0 row0" >c</th>
#       <td id="T_7df3f_row0_col0" class="data row0 col0" >0.997997</td>
#       <td id="T_7df3f_row0_col1" class="data row0 col1" >510.000000</td>
#       <td id="T_7df3f_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_7df3f_row0_col3" class="data row0 col3" >0.693447</td>
#       <td id="T_7df3f_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_7df3f_row0_col5" class="data row0 col5" >0.510721</td>
#       <td id="T_7df3f_row0_col6" class="data row0 col6" >0.043941</td>
#       <td id="T_7df3f_row0_col7" class="data row0 col7" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_7df3f_level0_row1" class="row_heading level0 row1" >d</th>
#       <td id="T_7df3f_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_7df3f_row1_col1" class="data row1 col1" >0.666891</td>
#       <td id="T_7df3f_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_7df3f_row1_col3" class="data row1 col3" >0.027207</td>
#       <td id="T_7df3f_row1_col4" class="data row1 col4" >125.400000</td>
#       <td id="T_7df3f_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_7df3f_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_7df3f_row1_col7" class="data row1 col7" >-0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_7df3f_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_7df3f_row2_col0" class="data row2 col0" >0.015957</td>
#       <td id="T_7df3f_row2_col1" class="data row2 col1" >0.003989</td>
#       <td id="T_7df3f_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_7df3f_row2_col3" class="data row2 col3" >0.017950</td>
#       <td id="T_7df3f_row2_col4" class="data row2 col4" >0.896197</td>
#       <td id="T_7df3f_row2_col5" class="data row2 col5" >2.613987</td>
#       <td id="T_7df3f_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_7df3f_row2_col7" class="data row2 col7" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fi_temp_df = get_feature_importances(data=test_df, num_features=[], cat_features=['c', 'd'], target='target_clf_multi', task='clf_multiable', method='all')
fi_temp_df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_4f6e1_row0_col0, #T_4f6e1_row0_col1, #T_4f6e1_row0_col3, #T_4f6e1_row0_col4, #T_4f6e1_row0_col6, #T_4f6e1_row0_col7, #T_4f6e1_row2_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4f6e1_row0_col2, #T_4f6e1_row1_col0, #T_4f6e1_row1_col1, #T_4f6e1_row1_col2, #T_4f6e1_row1_col3, #T_4f6e1_row1_col5, #T_4f6e1_row1_col6, #T_4f6e1_row1_col7, #T_4f6e1_row2_col1, #T_4f6e1_row2_col2, #T_4f6e1_row2_col4, #T_4f6e1_row2_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4f6e1_row0_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_4f6e1_row1_col4 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_4f6e1_row2_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_4f6e1_row2_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_4f6e1_row2_col7 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_4f6e1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Chi_Square_Crosstab</th>
#       <th class="col_heading level0 col1" >Chi_Square</th>
#       <th class="col_heading level0 col2" >ANOVA</th>
#       <th class="col_heading level0 col3" >MI Scores</th>
#       <th class="col_heading level0 col4" >LGBM Imp.</th>
#       <th class="col_heading level0 col5" >PI mean</th>
#       <th class="col_heading level0 col6" >PI std</th>
#       <th class="col_heading level0 col7" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f6e1_level0_row0" class="row_heading level0 row0" >d</th>
#       <td id="T_4f6e1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4f6e1_row0_col1" class="data row0 col1" >1777.384083</td>
#       <td id="T_4f6e1_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_4f6e1_row0_col3" class="data row0 col3" >2.304834</td>
#       <td id="T_4f6e1_row0_col4" class="data row0 col4" >4051.800000</td>
#       <td id="T_4f6e1_row0_col5" class="data row0 col5" >0.895981</td>
#       <td id="T_4f6e1_row0_col6" class="data row0 col6" >0.024302</td>
#       <td id="T_4f6e1_row0_col7" class="data row0 col7" >0.833333</td>
#     </tr>
#     <tr>
#       <th id="T_4f6e1_level0_row1" class="row_heading level0 row1" >c</th>
#       <td id="T_4f6e1_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_4f6e1_row1_col1" class="data row1 col1" >3.239473</td>
#       <td id="T_4f6e1_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_4f6e1_row1_col3" class="data row1 col3" >0.002292</td>
#       <td id="T_4f6e1_row1_col4" class="data row1 col4" >1574.400000</td>
#       <td id="T_4f6e1_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_4f6e1_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_4f6e1_row1_col7" class="data row1 col7" >-0.833333</td>
#     </tr>
#     <tr>
#       <th id="T_4f6e1_level0_row2" class="row_heading level0 row2" >TT (Sec)</th>
#       <td id="T_4f6e1_row2_col0" class="data row2 col0" >0.014961</td>
#       <td id="T_4f6e1_row2_col1" class="data row2 col1" >0.002992</td>
#       <td id="T_4f6e1_row2_col2" class="data row2 col2" >0.000998</td>
#       <td id="T_4f6e1_row2_col3" class="data row2 col3" >0.028921</td>
#       <td id="T_4f6e1_row2_col4" class="data row2 col4" >2.840644</td>
#       <td id="T_4f6e1_row2_col5" class="data row2 col5" >2.549646</td>
#       <td id="T_4f6e1_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_4f6e1_row2_col7" class="data row2 col7" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
